# %%
import os
from datetime import datetime

# Compile all the research data into a structured format for the competitive analysis report

report_data = {
    "metadata": {
        "title": "Analisi Competitiva - Mercato IT e Cybersecurity Roma EUR-Ostia Lido",
        "date": datetime.now().strftime("%d/%m/%Y"),
        "geographic_area": "Roma - dall'EUR fino a Ostia Lido",
        "sector": "Assistenza IT, Cybersecurity, Managed Services"
    },
    
    "competitors": [
        {
            "name": "Negg Group S.r.l.",
            "size": "Media (50-249 dipendenti)",
            "founded": "2012",
            "addresses": [
                "Piazza del Popolo 18, 00186 Roma (Sede Legale)",
                "Via del Corso 267, 00186 Roma (Sede Operativa)"
            ],
            "contacts": {
                "phone": "(+39) 06 21126804",
                "email": "info@negg.group",
                "website": "https://negg.group/"
            },
            "services": [
                "CyberSOC Intelligence Solutions (BigData Analytics, ML, Deep Learning)",
                "SCADA 360 (OT/IT Security per automazione industriale)",
                "Cyber & Networks Simulator (training)",
                "Assessment & Gap Analysis",
                "End-Point Network Protection"
            ],
            "certifications": "Varie certificazioni (dettagli sul sito)",
            "partnerships": "Non specificato",
            "target_clients": "Enterprise e Pubblica Amministrazione",
            "pricing": {
                "min_project": "$25,000+",
                "hourly_rate": "$300+/hr",
                "model": "Progetti enterprise di alto valore"
            },
            "online_presence": {
                "website_quality": "Professionale e tecnico",
                "social": "2,740 followers LinkedIn",
                "reviews": "Non ancora recensito su piattaforme pubbliche"
            },
            "swot": {
                "strengths": [
                    "Expertise tecnica avanzata (ML, Deep Learning)",
                    "Focus su enterprise e PA",
                    "Soluzioni proprietarie innovative (CyberSOC)",
                    "Team numeroso e qualificato"
                ],
                "weaknesses": [
                    "Prezzi molto elevati ($300+/hr)",
                    "Assenza di recensioni pubbliche",
                    "Posizionamento solo su clienti enterprise",
                    "Scarsa presenza nella zona EUR-Ostia (sede centro Roma)"
                ],
                "opportunities": [
                    "Espansione verso PMI con soluzioni scalate",
                    "Maggiore presenza online e recensioni",
                    "Servizi managed più accessibili"
                ],
                "threats": [
                    "Competitor più agili su PMI",
                    "Costi elevati in periodo economico difficile"
                ]
            }
        },
        {
            "name": "CyberSA",
            "size": "Piccola-Media (25+ dipendenti)",
            "founded": "Non specificato",
            "addresses": [
                "Via Delle Conce, 20 – 00154 Roma",
                "Via Foro Buonaparte, 12 Milano (ufficio secondario)"
            ],
            "contacts": {
                "email": "info@cybersa.it",
                "website": "Non specificato"
            },
            "services": [
                "Cyber Risk Assessment",
                "Delivery (implementazione soluzioni)",
                "Cyber Risk Gap Analysis",
                "Continuous Business & Education",
                "Gestione della Sicurezza",
                "Consulenza Cyber strategica",
                "Protezione Dati",
                "Formazione aziendale"
            ],
            "certifications": "Oltre 100 certificazioni nazionali e internazionali",
            "partnerships": "Partner tecnologici principali (non specificati nel dettaglio)",
            "target_clients": "B2B - Italia, Europa, USA (30+ clienti attivi)",
            "pricing": {
                "model": "Non specificato pubblicamente"
            },
            "online_presence": {
                "website_quality": "Non valutato",
                "social": "Presenza a eventi internazionali (London Tech Week, Dubai)",
                "reviews": "Testimonianze positive ma senza valutazioni numeriche"
            },
            "swot": {
                "strengths": [
                    "Oltre 100 certificazioni",
                    "Approccio metodologico strutturato (4 fasi)",
                    "Presenza internazionale",
                    "Soluzione proprietaria CyberSAM",
                    "Membro CYBER 4.0 Competence Center"
                ],
                "weaknesses": [
                    "Prezzi non trasparenti",
                    "Scarsa presenza recensioni online",
                    "Informazioni limitate su sito web"
                ],
                "opportunities": [
                    "Maggiore trasparenza sui prezzi",
                    "Espansione presenza digitale",
                    "Focus su territorio Roma Sud"
                ],
                "threats": [
                    "Competitor più trasparenti sui prezzi",
                    "Mancanza visibilità online"
                ]
            }
        },
        {
            "name": "TimeZeroTeam",
            "size": "Piccola (dimensione non specificata)",
            "founded": "Non specificato",
            "addresses": [
                "Via Tommaso Arciadiacono, 66h - Roma"
            ],
            "contacts": {
                "phone": "800.035.112",
                "email": "Info@timezeroteam.com"
            },
            "services": [
                "Assistenza sistemistica in loco e remota",
                "Managed Services con monitoraggio proattivo",
                "Backup e disaster recovery",
                "Reperibilità tecnica fuori orario",
                "Supporto server e dispositivi aziendali"
            ],
            "certifications": "Non specificato",
            "partnerships": "Non specificato",
            "target_clients": "PMI e professionisti zona EUR, Torrino, Laurentina, Ostia, Pomezia, Ardeatina",
            "pricing": {
                "model": "Pay-per-Use flessibile",
                "contracts": "Mensili senza vincoli, cessabili con 30 giorni preavvio",
                "initial": "Analisi e sopralluogo gratuiti"
            },
            "online_presence": {
                "website_quality": "Non valutato",
                "coverage": "Forte presenza territoriale Roma Sud",
                "reviews": "Non disponibili"
            },
            "swot": {
                "strengths": [
                    "Copertura specifica zona EUR-Ostia (target geografico perfetto)",
                    "Modello flessibile pay-per-use",
                    "Nessun vincolo contrattuale",
                    "Sopralluogo gratuito",
                    "Monitoraggio proattivo",
                    "Apparati temporanei in emergenza"
                ],
                "weaknesses": [
                    "Dimensione piccola",
                    "Assenza certificazioni note",
                    "Scarsa presenza online",
                    "Nessuna recensione pubblica"
                ],
                "opportunities": [
                    "Espansione servizi cybersecurity avanzati",
                    "Acquisizione certificazioni",
                    "Miglioramento presenza digitale",
                    "Partnership tecnologiche"
                ],
                "threats": [
                    "Competitor con maggiori risorse",
                    "Mancanza di brand recognition"
                ]
            }
        },
        {
            "name": "ConsulTechnologies S.r.l.",
            "size": "Non specificato",
            "founded": "Non specificato",
            "addresses": [
                "Via Ivanoe Bonomi, 50 - 00139 Roma"
            ],
            "contacts": {
                "website": "Non specificato"
            },
            "services": [
                "Manutenzione ordinaria e server",
                "Intervento online e onsite",
                "Recupero dati da backup",
                "Consulenza acquisti e contratti fonia",
                "Monitoraggio server 24/7",
                "Sistema di ticketing",
                "Gestione centralini VoIP",
                "Ruolo amministratore GDPR",
                "Disaster Recovery remoto",
                "Antivirus endpoint"
            ],
            "certifications": "Non specificato",
            "partnerships": "Non specificato",
            "target_clients": "PMI",
            "pricing": {
                "starter_pack": "€700 (10 ore incluse)",
                "medium_pack": "da €200/mese (supporto illimitato)",
                "full_pack": "da €500/mese (aziende complesse)",
                "model": "Pacchetti mensili scalabili"
            },
            "online_presence": {
                "website_quality": "Non valutato",
                "reviews": "Non disponibili"
            },
            "swot": {
                "strengths": [
                    "Prezzi trasparenti e competitivi",
                    "Pacchetti scalabili per diverse dimensioni aziendali",
                    "Servizi completi (GDPR, VoIP, DR)",
                    "Supporto illimitato nei pacchetti superiori"
                ],
                "weaknesses": [
                    "Sede Roma Nord (lontano da EUR-Ostia)",
                    "Assenza informazioni su certificazioni",
                    "Nessuna recensione disponibile",
                    "Scarsa presenza online"
                ],
                "opportunities": [
                    "Espansione geografica verso Roma Sud",
                    "Maggiore visibilità online",
                    "Acquisizione recensioni clienti"
                ],
                "threats": [
                    "Competitor con presenza territoriale migliore",
                    "Mancanza di differenziazione"
                ]
            }
        },
        {
            "name": "JoyComm (Joy System)",
            "size": "Non specificato",
            "founded": "Non specificato",
            "addresses": [
                "Viale Città d'Europa, 681 – 00144 Roma EUR"
            ],
            "contacts": {
                "phone": "800808758",
                "piva": "14940701007"
            },
            "services": [
                "Sicurezza informatica aziendale 360°",
                "Email Security",
                "Identity Management",
                "Networking & Wi-Fi",
                "Consulenza GDPR"
            ],
            "certifications": [
                "Fortinet Certified Trainer (FCT) - 1",
                "Fortinet Certified Professional (FCP) - FortiGate Admin (10), FortiManager (3), FortiNAC (3)",
                "Fortinet Certified Solution Specialist (FCSS) - Enterprise Firewall (6), SD-WAN Architect (5), OT Security (2)",
                "SentinelOne Pre-Sales/Tech e Sales Accreditation",
                "Claroty Implementation & Support Engineer"
            ],
            "partnerships": "Fortinet, SentinelOne, Kaspersky, Proofpoint, VMware",
            "target_clients": "Aziende (focus sicurezza)",
            "pricing": {
                "model": "Non specificato pubblicamente"
            },
            "online_presence": {
                "website_quality": "Non valutato",
                "reviews": "Non disponibili"
            },
            "swot": {
                "strengths": [
                    "Sede nell'EUR (posizione strategica perfetta)",
                    "Certificazioni Fortinet di altissimo livello",
                    "Partnership con vendor leader (Fortinet, SentinelOne)",
                    "Specializzazione security avanzata",
                    "Competenze OT/ICS security"
                ],
                "weaknesses": [
                    "Prezzi non trasparenti",
                    "Assenza recensioni pubbliche",
                    "Focus principalmente su security (meno managed services completi)"
                ],
                "opportunities": [
                    "Espansione servizi managed completi",
                    "Maggiore visibilità e marketing",
                    "Trasparenza prezzi per PMI"
                ],
                "threats": [
                    "Competitor con offerta più completa",
                    "Percezione di prezzi elevati"
                ]
            }
        },
        {
            "name": "N&C System Integrator",
            "size": "Media-Grande",
            "founded": "1982",
            "addresses": [
                "Sede operativa a Roma (indirizzo specifico non fornito)",
                "Sede legale: Veglie (LE)",
                "Altre sedi: Napoli, Milano, Torino"
            ],
            "contacts": {
                "website": "Non specificato"
            },
            "services": [
                "Consulenza e progettazione IT",
                "Networking e infrastrutture di rete",
                "Datacenter & Cloud solutions",
                "Security & CyberSecurity",
                "ICT Managed Services",
                "Unified Communications"
            ],
            "certifications": "Gold Solution Provider",
            "partnerships": "Fortinet (Expert Partner)",
            "target_clients": "Enterprise e grandi aziende",
            "pricing": {
                "model": "Non specificato pubblicamente"
            },
            "online_presence": {
                "website_quality": "Non valutato",
                "coverage": "Presenza nazionale e internazionale",
                "reviews": "Non disponibili"
            },
            "swot": {
                "strengths": [
                    "Esperienza dal 1982 (oltre 40 anni)",
                    "Presenza nazionale e internazionale",
                    "Certificazioni Gold",
                    "Partnership Fortinet Expert",
                    "Offerta completa (networking, cloud, security)"
                ],
                "weaknesses": [
                    "Indirizzo Roma non specificato",
                    "Focus su grandi aziende (meno PMI)",
                    "Prezzi probabilmente elevati",
                    "Assenza recensioni"
                ],
                "opportunities": [
                    "Espansione verso PMI locali",
                    "Maggiore presenza territoriale Roma Sud",
                    "Servizi managed più accessibili"
                ],
                "threats": [
                    "Competitor più agili e focalizzati su PMI locali",
                    "Percezione di azienda 'troppo grande' per PMI"
                ]
            }
        }
    ]
}

# Create comparative tables data
pricing_comparison = [
    ["Competitor", "Modello Pricing", "Range Prezzi", "Target"],
    ["Negg Group", "Progetto", "$25,000+ min, $300+/hr", "Enterprise"],
    ["CyberSA", "Non specificato", "Non pubblico", "B2B medio-grandi"],
    ["TimeZeroTeam", "Pay-per-Use", "Flessibile, sopralluogo gratuito", "PMI locali"],
    ["ConsulTechnologies", "Pacchetti mensili", "€200-500/mese + €700 starter", "PMI"],
    ["JoyComm", "Non specificato", "Non pubblico", "Aziende security-focused"],
    ["N&C System", "Non specificato", "Non pubblico (probabilmente alto)", "Enterprise"]
]

certifications_comparison = [
    ["Competitor", "Certificazioni Principali", "Partnership Tecnologiche"],
    ["Negg Group", "Varie (non dettagliate)", "Non specificate"],
    ["CyberSA", "100+ certificazioni nazionali/internazionali", "Partner principali non dettagliati"],
    ["TimeZeroTeam", "Non specificate", "Non specificate"],
    ["ConsulTechnologies", "Non specificate", "Non specificate"],
    ["JoyComm", "Fortinet FCT, FCP, FCSS (multiple), SentinelOne, Claroty", "Fortinet, SentinelOne, Kaspersky, Proofpoint, VMware"],
    ["N&C System", "Gold Solution Provider", "Fortinet Expert Partner"]
]

geographic_coverage = [
    ["Competitor", "Sede Roma", "Copertura EUR-Ostia", "Valutazione Posizionamento"],
    ["Negg Group", "Centro (Popolo, Corso)", "❌ Bassa", "Lontano dalla zona target"],
    ["CyberSA", "Via Delle Conce (Testaccio)", "⚠️ Media", "Relativamente vicino ma non ottimale"],
    ["TimeZeroTeam", "Via Arciadiacono", "✅ Ottima", "Specializzati EUR-Ostia-Torrino-Laurentina"],
    ["ConsulTechnologies", "Via Bonomi (Nord Roma)", "❌ Bassa", "Molto lontano dalla zona target"],
    ["JoyComm", "Viale Città d'Europa (EUR)", "✅ Ottima", "Posizione perfetta nell'EUR"],
    ["N&C System", "Roma (indirizzo non specificato)", "⚠️ Non valutabile", "Presenza Roma ma dettagli mancanti"]
]

print("✅ Dati competitivi strutturati e pronti per il report")
print(f"✅ Identificati {len(report_data['competitors'])} competitor principali")
print(f"✅ Analisi SWOT completata per tutti i competitor")
print(f"✅ Tabelle comparative preparate: pricing, certificazioni, copertura geografica")
# Out:
# ✅ Dati competitivi strutturati e pronti per il report
# ✅ Identificati 6 competitor principali
# ✅ Analisi SWOT completata per tutti i competitor
# ✅ Tabelle comparative preparate: pricing, certificazioni, copertura geografica
